# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
df.head()

# %%
df.describe()

# %%
df.plot()
plt.show()

# %% [markdown]
# The dataset shows a general trend between study time and scores.
# Although the dataset is small, it helps demonstrate basic data analysis steps.
# This project focuses on practice rather than drawing deep conclusions.
